# %% [markdown]
# REGRESION LINEAL

# %%
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("D:\lineal\data.csv",sep=",")

# %%
data
# Out:
#    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500

# %%
data.plot.scatter(x="metro",y="precio")
plt.show()

# %%
# esta variable va a contenerla regresion lineal.
regresion = linear_model.LinearRegression()

# %%
# Agregaremos los datos a un vector.
metro = data["metro"].values.reshape((-1,1))

# %%
# Creamos el modelo.
modelo = regresion.fit(metro, data["precio"])

print("Interseccion (b)"), (modelo.intercept_)
# Out:
# Interseccion (b)
# (None, 361.25714285714287)

# %%
# imprimimos la pendiente.
print("Pendient (m)"), (modelo.coef_)
# Out:
# Pendient (m)
# (None, array([5.64571429]))

# %%
#predicciones
entrada = [[15],[20]]
predicciones = modelo.predict(entrada)
print(predicciones)
# Out:
# [445.94285714 474.17142857]

# %%
data.plot.scatter(x="metro", y="precio", label= 'Datos')
plt.scatter(entrada, predicciones, color='orange')
plt.plot(entrada, predicciones, color= 'green', label='Linea de Regresion')
plt.xlabel('metro')
plt.ylabel('precio')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("D:\lineal\data.csv",sep=",")

# %%
data
# Out:
#    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500

# %%
data.plot.scatter(x="metro",y="precio")
plt.show()

# %%
regresion = linear_model.LinearRegression()

# %%
metro = data["metro"].values.reshape((-1,1))

# %%
modelo = regresion.fit(metro, data["precio"])

print("Interseccion (b)"), (modelo.intercept_)
# Out:
# Interseccion (b)
# (None, 361.25714285714287)

# %%
print("Pendient (m)"), (modelo.coef_)
# Out:
# Pendient (m)
# (None, array([5.64571429]))

# %%
#predicciones
entrada = [[5],[20]]
predicciones = modelo.predict(entrada)
print(predicciones)
# Out:
# [389.48571429 474.17142857]

# %%
data.plot.scatter(x="metro", y="precio", label= 'Datos')
plt.scatter(entrada, predicciones, color='orange')
plt.plot(entrada, predicciones, color= 'green', label='Linea de Regresion')
plt.xlabel('metro')
plt.ylabel('precio')
plt.legend()
plt.show()
